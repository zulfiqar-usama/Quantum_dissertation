# %%
from nnv import NNV

# %%
layersList = [
    {"title":"Input\n layer", "units": 4, "color": "mediumblue"},
    {"title":"Hidden\n layer", "units": 4},
    {"title":"Quantum\n layer", "units": 2, "color": "red", "edges_width":2},
    {"title":"Output\n layer", "units": 1,"color": "mediumblue"},
]

NNV(layersList).render(save_to_file="HQNN.png")
# Out:
# (<Figure size 432x288 with 1 Axes>, <AxesSubplot:>)

# %%
layersList = [
    {"title":"Input\n layer", "units": 4, "color": "mediumblue"},
    {"title":"Hidden\n layer", "units": 4},
    {"title":"Output\n layer", "units": 4,"color": "mediumblue"},
]

NNV(layersList).render(save_to_file="NN.png")
# Out:
# (<Figure size 432x288 with 1 Axes>, <AxesSubplot:>)
